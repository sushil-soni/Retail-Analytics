# %% [markdown]
# # Database Connection
#
# ## Objective
#
# Connect Python with the MySQL database (`retail_analytics`) and verify that the connection is successful.

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
HOST = "localhost"
PORT = 3306

USER = "root"

PASSWORD = "root"

DATABASE = "retail_analysis"

# %%
connection_string = (
    f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

engine = create_engine(connection_string)

print("Database Engine Created Successfully")
# Out:
# Database Engine Created Successfully

# %%
query = "SELECT COUNT(*) AS total_customers FROM customers;"

df = pd.read_sql(query, engine)

df
# Out:
#    total_customers
# 0            99441

# %%
query = """
SHOW TABLES;
"""

tables = pd.read_sql(query, engine)

tables
# Out:
#   Tables_in_retail_analysis
# 0      category_translation
# 1                 customers
# 2                    detail
# 3               geolocation
# 4               order_items
# 5            order_payments
# 6             order_reviews
# 7                    orders
# 8                  products
# 9                   sellers

# %% [markdown]
# ## Observation
#
# - Successfully connected to the MySQL database.
# - Verified database accessibility.
# - Confirmed all tables are available.
#
# ## Next Step
#
# Load all tables into Pandas DataFrames for further data cleaning and analysis.
